# %% [markdown]
# https://colab.research.google.com/drive/1I7Q-7n0Gwl8-SqdNewQHcd2tPT5p0KcW?usp=sharing

# %% [markdown]
# ![certificado santiago olaya.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Certificado IBM PY0101EN _ Cognitive Class.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Certificado IBM DV0101EN _ Cognitive Class.jpg](data:image/jpeg;base64,...)
